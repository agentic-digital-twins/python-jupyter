# %%
# EIA ArcGIS Maps and Data Explorer
# This notebook helps you discover, download, and visualize EIA energy infrastructure data

# First, let's install required packages
import subprocess
import sys

def install_packages():
    packages = [
        'requests',
        'geopandas',
        'folium',
        'matplotlib',
        'pandas',
        'shapely',
        'contextily',
        'arcgis'
    ]
    
    for package in packages:
        try:
            __import__(package)
            print(f"✓ {package} already installed")
        except ImportError:
            print(f"Installing {package}...")
            subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])

install_packages()

# Import necessary libraries
import requests
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import json
from pathlib import Path
import urllib.parse
from arcgis.gis import GIS
from arcgis.features import FeatureLayer
import warnings
warnings.filterwarnings('ignore')

# Configure display options
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

class EIADataExplorer:
    """
    A class to explore and download EIA ArcGIS energy infrastructure data
    """
    
    def __init__(self):
        self.base_url = "https://atlas-eia.opendata.arcgis.com"
        self.services_url = f"{self.base_url}/data.json"
        self.gis = GIS()
        self.available_datasets = {}
        
    def discover_datasets(self):
        """
        Discover available datasets from the EIA ArcGIS portal
        """
        print("🔍 Discovering available EIA datasets...")
        
        try:
            # Get the data catalog
            response = requests.get(self.services_url)
            if response.status_code == 200:
                data = response.json()
                
                # Extract dataset information
                datasets = data.get('dataset', [])
                print(f"Found {len(datasets)} datasets")
                
                for i, dataset in enumerate(datasets):
                    title = dataset.get('title', 'Unknown')
                    identifier = dataset.get('identifier', '')
                    description = dataset.get('description', 'No description available')
                    
                    self.available_datasets[identifier] = {
                        'title': title,
                        'description': description,
                        'data': dataset
                    }
                    
                    print(f"\n{i+1}. {title}")
                    print(f"   ID: {identifier}")
                    print(f"   Description: {description[:100]}...")
                    
                    # Check for download formats
                    distributions = dataset.get('distribution', [])
                    formats = [d.get('format', 'Unknown') for d in distributions]
                    if formats:
                        print(f"   Available formats: {', '.join(set(formats))}")
                
                return self.available_datasets
                
        except Exception as e:
            print(f"Error discovering datasets: {e}")
            return self._discover_datasets_alternative()
    
    def _discover_datasets_alternative(self):
        """
        Alternative method to discover datasets by searching common energy infrastructure layers
        """
        print("🔍 Using alternative discovery method...")
        
        # Common EIA layer names and their service URLs
        common_layers = {
            'power_plants': 'https://services7.arcgis.com/FGr1D95XCGALIdra/arcgis/rest/services/Power_Plants_US_EIA/FeatureServer/0',
            'transmission_lines': 'https://services7.arcgis.com/FGr1D95XCGALIdra/arcgis/rest/services/US_Electric_Power_Transmission_Lines/FeatureServer/0',
            'natural_gas_pipelines': 'https://services7.arcgis.com/FGr1D95XCGALIdra/arcgis/rest/services/Natural_Gas_Interstate_and_Intrastate_Pipelines/FeatureServer/0',
            'refineries': 'https://services7.arcgis.com/FGr1D95XCGALIdra/arcgis/rest/services/Petroleum_Refineries_US_EIA/FeatureServer/0',
            'coal_mines': 'https://services7.arcgis.com/FGr1D95XCGALIdra/arcgis/rest/services/Coal_Mines_US_EIA/FeatureServer/0',
            'lng_terminals': 'https://services7.arcgis.com/FGr1D95XCGALIdra/arcgis/rest/services/LNG_Import_Export_Terminals/FeatureServer/0'
        }
        
        for layer_name, service_url in common_layers.items():
            try:
                # Try to access the service info
                info_url = f"{service_url}?f=json"
                response = requests.get(info_url)
                
                if response.status_code == 200:
                    info = response.json()
                    
                    self.available_datasets[layer_name] = {
                        'title': info.get('name', layer_name),
                        'description': info.get('description', 'EIA energy infrastructure data'),
                        'service_url': service_url,
                        'geometry_type': info.get('geometryType', 'Unknown'),
                        'fields': info.get('fields', [])
                    }
                    
                    print(f"✓ Found: {layer_name}")
                    
            except Exception as e:
                print(f"✗ Could not access {layer_name}: {e}")
        
        return self.available_datasets
    
    def get_supported_formats(self, dataset_id):
        """
        Get supported download formats for a specific dataset
        """
        if dataset_id not in self.available_datasets:
            print(f"Dataset {dataset_id} not found")
            return []
        
        # Common ArcGIS service formats
        formats = [
            'GeoJSON',
            'Shapefile',
            'KML',
            'CSV',
            'JSON',
            'GeoTIFF' # for raster data
        ]
        
        print(f"Supported formats for {dataset_id}:")
        for fmt in formats:
            print(f"  - {fmt}")
        
        return formats
    
    def download_dataset(self, dataset_id, format_type='GeoJSON', output_dir='./data'):
        """
        Download a dataset in the specified format
        
        Args:
            dataset_id: The dataset identifier
            format_type: Format to download (GeoJSON, Shapefile, KML, CSV, etc.)
            output_dir: Directory to save the downloaded data
        """
        if dataset_id not in self.available_datasets:
            print(f"Dataset {dataset_id} not found")
            return None
        
        # Create output directory
        Path(output_dir).mkdir(exist_ok=True)
        
        dataset = self.available_datasets[dataset_id]
        print(f"debug download_dataset = {dataset}")

        import json

        # Assuming your JSON is loaded into the variable 'data'
        service_url = next(
            (dist["accessURL"] for dist in data["data"]["distribution"] if dist.get("format") == format_type),
            None
        )
        
        print(service_url)
        try:
            # Try to use the service URL if available
            if service_url:
                
                # Download based on format
                if format_type.upper() == 'GEOJSON':
                    return self._download_geojson(service_url, dataset_id, output_dir)
                elif format_type.upper() == 'SHAPEFILE':
                    return self._download_shapefile(service_url, dataset_id, output_dir)
                elif format_type.upper() == 'KML':
                    return self._download_kml(service_url, dataset_id, output_dir)
                elif format_type.upper() == 'CSV':
                    return self._download_csv(service_url, dataset_id, output_dir)
            else:
                print(f"DEBUG service_url not in dataset")
                    
        except Exception as e:
            print(f"Error downloading {dataset_id}: {e}")
            return None
    
    def _download_geojson(self, service_url, dataset_id, output_dir):
        """Download data as GeoJSON"""
        print(f"📥 Downloading {dataset_id} as GeoJSON...")
        
        # Query all features
        query_url = f"{service_url}/query"
        params = {
            'where': '1=1',
            'outFields': '*',
            'f': 'geojson'
        }
        
        response = requests.get(query_url, params=params)
        
        if response.status_code == 200:
            output_file = Path(output_dir) / f"{dataset_id}.geojson"
            with open(output_file, 'w') as f:
                f.write(response.text)
            
            print(f"✓ Downloaded: {output_file}")
            return str(output_file)
        else:
            print(f"✗ Failed to download: {response.status_code}")
            return None
    
    def _download_shapefile(self, service_url, dataset_id, output_dir):
        """Download data as Shapefile"""
        print(f"📥 Downloading {dataset_id} as Shapefile...")
        
        # First get as GeoJSON, then convert to Shapefile
        geojson_file = self._download_geojson(service_url, dataset_id, output_dir)
        
        if geojson_file:
            try:
                # Read GeoJSON and save as Shapefile
                gdf = gpd.read_file(geojson_file)
                output_file = Path(output_dir) / f"{dataset_id}.shp"
                gdf.to_file(output_file)
                
                print(f"✓ Converted to Shapefile: {output_file}")
                return str(output_file)
            except Exception as e:
                print(f"✗ Error converting to Shapefile: {e}")
                return geojson_file
        
        return None
    
    def _download_kml(self, service_url, dataset_id, output_dir):
        """Download data as KML"""
        print(f"📥 Downloading {dataset_id} as KML...")
        
        # First get as GeoJSON, then convert to KML
        geojson_file = self._download_geojson(service_url, dataset_id, output_dir)
        
        if geojson_file:
            try:
                # Read GeoJSON and save as KML
                gdf = gpd.read_file(geojson_file)
                output_file = Path(output_dir) / f"{dataset_id}.kml"
                gdf.to_file(output_file, driver='KML')
                
                print(f"✓ Converted to KML: {output_file}")
                return str(output_file)
            except Exception as e:
                print(f"✗ Error converting to KML: {e}")
                return geojson_file
        
        return None
    
    def _download_csv(self, service_url, dataset_id, output_dir):
        """Download data as CSV"""
        print(f"📥 Downloading {dataset_id} as CSV...")
        
        # Query all features without geometry
        query_url = f"{service_url}/query"
        params = {
            'where': '1=1',
            'outFields': '*',
            'returnGeometry': 'false',
            'f': 'json'
        }
        
        response = requests.get(query_url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            features = data.get('features', [])
            
            if features:
                # Convert to DataFrame
                records = [feature['attributes'] for feature in features]
                df = pd.DataFrame(records)
                
                output_file = Path(output_dir) / f"{dataset_id}.csv"
                df.to_csv(output_file, index=False)
                
                print(f"✓ Downloaded: {output_file}")
                return str(output_file)
        
        print(f"✗ Failed to download CSV")
        return None
    
    def visualize_dataset(self, dataset_file, dataset_id):
        """
        Visualize a downloaded dataset
        """
        print(f"🗺️ Visualizing {dataset_id}...")
        
        try:
            # Read the data
            if dataset_file.endswith('.geojson') or dataset_file.endswith('.shp'):
                gdf = gpd.read_file(dataset_file)
            elif dataset_file.endswith('.csv'):
                df = pd.read_csv(dataset_file)
                print(f"CSV contains {len(df)} records")
                print(f"Columns: {list(df.columns)}")
                return df.head()
            else:
                print(f"Unsupported file format for visualization")
                return None
            
            print(f"Loaded {len(gdf)} features")
            print(f"Geometry type: {gdf.geom_type.iloc[0] if len(gdf) > 0 else 'Unknown'}")
            print(f"Coordinate Reference System: {gdf.crs}")
            
            # Create static plot
            fig, ax = plt.subplots(1, 1, figsize=(15, 10))
            gdf.plot(ax=ax, alpha=0.7, edgecolor='black', linewidth=0.5)
            ax.set_title(f"{dataset_id} - {len(gdf)} features", fontsize=16)
            ax.set_xlabel("Longitude")
            ax.set_ylabel("Latitude")
            plt.tight_layout()
            plt.show()
            
            # Create interactive map
            if len(gdf) > 0:
                # Convert to WGS84 for folium
                gdf_wgs84 = gdf.to_crs(epsg=4326)
                
                # Calculate center
                bounds = gdf_wgs84.bounds
                center_lat = (bounds.miny.min() + bounds.maxy.max()) / 2
                center_lon = (bounds.minx.min() + bounds.maxx.max()) / 2
                
                # Create folium map
                m = folium.Map(location=[center_lat, center_lon], zoom_start=6)
                
                # Add data to map
                if gdf_wgs84.geom_type.iloc[0] == 'Point':
                    for idx, row in gdf_wgs84.iterrows():
                        folium.CircleMarker(
                            location=[row.geometry.y, row.geometry.x],
                            radius=5,
                            popup=f"{dataset_id} - Feature {idx}",
                            fillColor='red',
                            color='black',
                            weight=1,
                            fillOpacity=0.7
                        ).add_to(m)
                else:
                    folium.GeoJson(
                        gdf_wgs84,
                        style_function=lambda x: {
                            'fillColor': 'blue',
                            'color': 'black',
                            'weight': 2,
                            'fillOpacity': 0.7
                        }
                    ).add_to(m)
                
                return m
            
        except Exception as e:
            print(f"Error visualizing dataset: {e}")
            return None

# Initialize the explorer
explorer = EIADataExplorer()

print("🚀 EIA ArcGIS Data Explorer initialized!")
print("\nAvailable methods:")
print("- explorer.discover_datasets() - Find available datasets")
print("- explorer.get_supported_formats(dataset_id) - Check supported formats")
print("- explorer.download_dataset(dataset_id, format_type) - Download data")
print("- explorer.visualize_dataset(file_path, dataset_id) - Visualize data")

# Example usage
print("\n" + "="*50)
print("EXAMPLE USAGE")
print("="*50)

# Discover datasets
datasets = explorer.discover_datasets()

if datasets:
    print(f"\n📊 Found {len(datasets)} datasets")
    
    # Show available formats for first dataset
    first_dataset = list(datasets.keys())[0]
    print(f"\n🔍 Checking formats for: {first_dataset}")
    formats = explorer.get_supported_formats(first_dataset)
    
    print(f"\n💾 Example: Download {first_dataset} as GeoJSON")
    print(f"file_path = explorer.download_dataset('{first_dataset}', 'GeoJSON')")
    print(f"map_viz = explorer.visualize_dataset(file_path, '{first_dataset}')")
    
    # Try to download and visualize the first dataset
    try:
        print(f"\n🏃 Attempting to download and visualize {first_dataset}...")
        file_path = explorer.download_dataset(first_dataset, 'GeoJSON')
        
        if file_path:
            viz_result = explorer.visualize_dataset(file_path, first_dataset)
            if viz_result:
                print("✅ Visualization completed successfully!")
                
                # If it's a folium map, display it
                if hasattr(viz_result, '_repr_html_'):
                    print("📍 Interactive map created (scroll down to see it)")
                    viz_result
        
    except Exception as e:
        print(f"⚠️ Example failed: {e}")
        print("This is normal - try running the methods individually")

print("\n" + "="*50)
print("NEXT STEPS")
print("="*50)
print("1. Run: datasets = explorer.discover_datasets()")
print("2. Choose a dataset ID from the results")
print("3. Run: file_path = explorer.download_dataset('dataset_id', 'GeoJSON')")
print("4. Run: map_viz = explorer.visualize_dataset(file_path, 'dataset_id')")
print("5. The map_viz object will be an interactive Folium map you can explore!")
# Out:
# ✓ requests already installed
# ✓ geopandas already installed
# ✓ folium already installed
# ✓ matplotlib already installed
# ✓ pandas already installed
# ✓ shapely already installed
# ✓ contextily already installed
# ✓ arcgis already installed
# 🚀 EIA ArcGIS Data Explorer initialized!
#
# Available methods:
# - explorer.discover_datasets() - Find available datasets
# - explorer.get_supported_formats(dataset_id) - Check supported formats
# - explorer.download_dataset(dataset_id, format_type) - Download data
# - explorer.visualize_dataset(file_path, dataset_id) - Visualize data
#
# ==================================================
# EXAMPLE USAGE
# ==================================================
# 🔍 Discovering available EIA datasets...
# Found 145 datasets
#
# 1. Solar Resources
#    ID: https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0
#    Description: <span style='color:rgb(34, 34, 34); font-family:Roboto, &quot;Helvetica Neue&quot;, Helvetica, sans-...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 2. NERC Regions
#    ID: https://www.arcgis.com/home/item.html?id=1fc907a553964de3b2ee5e9224360c43&sublayer=0
#    Description: <DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>This polygon dataset represents approximate boundar...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 3. Petroleum Product Pipelines
#    ID: https://www.arcgis.com/home/item.html?id=b93f85a642b14dc6a46fe041c5dc2929&sublayer=0
#    Description: <div style='text-align:Left;'><div><div><p><span>Major petroleum product pipelines in the United Sta...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 4. Hydrocarbon Gas Liquids (HGL) Pipelines
#    ID: https://www.arcgis.com/home/item.html?id=2c31f58989d540ea961c1365dfea2d63&sublayer=0
#    Description: <div style='text-align:Left;'><div><div><p><span>Major hydrocarbon gas liquids (HGL) pipelines in th...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 5. Natural Gas Interstate and Intrastate Pipelines
#    ID: https://www.arcgis.com/home/item.html?id=4a158d2113f145039f71b80d07e2c19c&sublayer=0
#    Description: <div style='text-align:Left;'><div><div><p><span>This is a polyline dataset representing the major n...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 6. Natural Gas Processing Plants
#    ID: https://www.arcgis.com/home/item.html?id=1603bffa90024b9eb280215af7edc3bd&sublayer=23
#    Description: <div style='text-align:Left;'><div><div><p><span>Natural gas processing plants in the U.S as of 12/3...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 7. Sedimentary Basins
#    ID: https://www.arcgis.com/home/item.html?id=6542690951ca45f2a3c23a4325153d7d&sublayer=109
#    Description: ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 8. RTO Regions
#    ID: https://www.arcgis.com/home/item.html?id=b286c693074045b3ac9b5d7300162e99&sublayer=256
#    Description: <div style='text-align:Left;'><div><div><p><span>This feature class/shapefile represents the seven r...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 9. Uranium Mills and Heap Leach Facilities
#    ID: https://www.arcgis.com/home/item.html?id=ea0380a04eb74b5fa58123019d75e17c&sublayer=148
#    Description: <div style='text-align:Left;'><div><div><p><span>This is a point dataset representing uranium mills ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 10. Northeast Petroleum Reserves
#    ID: https://www.arcgis.com/home/item.html?id=16c1030d39b142fe9c9509d7c22f069c&sublayer=41
#    Description: <div style='text-align:Left;'><div><div><p><span>Northeast Home Heating Oil Reserve and the Northeas...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 11. Liquefied Natural Gas (LNG) Import and Export Terminals
#    ID: https://www.arcgis.com/home/item.html?id=e2e0a3828d3548b29aa03b7a53a4efb5&sublayer=254
#    Description: <div style='text-align:Left;'><div><div><p><span>This is a point dataset representing liquefied natu...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 12. Ethylene Crackers
#    ID: https://www.arcgis.com/home/item.html?id=2a3894eae1df438fab70d6f6f0a8867f&sublayer=253
#    Description: <div style='text-align:Left;'><div><div><p><span>Operating ethylene crackers in the United States. C...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 13. Crude Oil Rail Terminals
#    ID: https://www.arcgis.com/home/item.html?id=5a202c36715f4098b01081d2fb11afd3&sublayer=0
#    Description: Rail terminals that handle loading and unloading of crude oil. Created by EIA using publicly availab...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 14. Crude Oil Pipelines
#    ID: https://www.arcgis.com/home/item.html?id=ae809a7e79354d31ab37da8df6352f84&sublayer=0
#    Description: <div style='text-align:Left;'><div><div><p><span>Major crude oil pipelines in the United States and ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 15. Climate Zones - DOE Building America Program
#    ID: https://www.arcgis.com/home/item.html?id=0c432b67293048b6a4704232a26ca99f&sublayer=0
#    Description: <div>This map layer depicts the climate zone designations used by the  U.S. Department of Energy Bui...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 16. Border Crossings - Natural Gas
#    ID: https://www.arcgis.com/home/item.html?id=38d68d3a72914434b8eb44a3507629dd&sublayer=0
#    Description: U.S. border crossings of natural gas pipelines as of 2017. A crossing point represents one or more p...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 17. Border Crossings - Liquids
#    ID: https://www.arcgis.com/home/item.html?id=08bedfd112254352815ee4c53511d6b2&sublayer=0
#    Description: <span style='font-family: &quot;Avenir Next W01&quot;, &quot;Avenir Next W00&quot;, &quot;Avenir Nex...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 18. Border Crossings - Electricity
#    ID: https://www.arcgis.com/home/item.html?id=ee54f482c06647e28cc845710dec3ddf&sublayer=0
#    Description: U.S. border crossing points of electric transmission lines. A crossing point represents one or more ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 19. Balancing Authorities
#    ID: https://www.arcgis.com/home/item.html?id=09550598922b429ca9f06b9a067257bd&sublayer=255
#    Description: <div style='text-align:Left;'><div><div><p style='margin:0 0 0 0;'><span><span>This feature class/sh...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 20. Uranium In-Situ Leach Plants
#    ID: https://www.arcgis.com/home/item.html?id=841b3c0ae01a405e8e87d2e3152873bd&sublayer=149
#    Description: <div style='text-align:Left;'><div><div><p><span>This is a point dataset representing uranium in-sit...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 21. Ethanol Plants
#    ID: https://www.arcgis.com/home/item.html?id=3f984029aadc4647ac4025675799af90&sublayer=112
#    Description: <div style='text-align:Left;'><div><div><p><span>The attribute data for this point dataset come from...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 22. Renewable Diesel and Other Biofuels
#    ID: https://www.arcgis.com/home/item.html?id=b6327e97caef493d9c74695d420cbc11&sublayer=245
#    Description: <div style='text-align:Left;'><div><div><p style='margin:0 0 11 0;'><span style='font-size:12pt'>The...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 23. Petroleum Refineries
#    ID: https://www.arcgis.com/home/item.html?id=6547eda91ef84cc386e23397cf834524&sublayer=22
#    Description: <div style='text-align:Left;'><div><div><p style='margin:8 0 11 0;'><span>The attribute data for thi...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 24. Biodiesel Plants
#    ID: https://www.arcgis.com/home/item.html?id=79dad60ce89c47519452a2959d49acd8&sublayer=113
#    Description: ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 25. Strategic Petroleum Reserves
#    ID: https://www.arcgis.com/home/item.html?id=5e5319e61b324ab1a61b270878bad660&sublayer=42
#    Description: <div style='text-align:Left;'><div><div><p><span>These data were obtained from the </span><a href='h...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 26. ShalePlay Midland SpraberryLower Boundary EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=3d8cb0d38b3c4444b33c76d7bed114aa&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 27. ShalePlay Midland Spraberry Middle Isopach EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=568e90a9096c466aafe218d7b8749964&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 28. ShalePlay Midland Spraberry Lower Elevation EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=0e04651bb53b43a6866e64f2da033871&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 29. ShalePlay Midland Spraberry Middle Elevation EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=4565199bd51345e18493a734eaa34342&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 30. ShalePlay Midland Spraberry Upper Isopach EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=cff84c364d5d4ee2ae7b15af332cc2fa&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 31. ShalePlay Midland Spraberry Upper Elevation EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=cff12a23998042f88f04edb769c00638&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 32. {{name}}
#    ID: https://www.arcgis.com/home/item.html?id=37a875ff3611496883b7ccca97f0f5f4
#    Description: {{description}}...
#    Available formats: Web Page
#
# 33. RECS Mobile
#    ID: https://www.arcgis.com/home/item.html?id=d81cd9c7f14341e2b7873cba4b2244b3
#    Description: <p>We periodically conduct the <a href='https://www.eia.gov/consumption/residential' rel='nofollow u...
#    Available formats: Web Page
#
# 34. RECS Desktop
#    ID: https://www.arcgis.com/home/item.html?id=8dfec258438441b68c9c4e1c41589f2f
#    Description: <p>We periodically conduct the <a href='https://www.eia.gov/consumption/residential' rel='nofollow u...
#    Available formats: Web Page
#
# 35. Hydrocarbon Gas Liquids (HGL) Market Hubs
#    ID: https://www.arcgis.com/home/item.html?id=228cc32d543c493f97de3690115e8b9c&sublayer=0
#    Description: <p style='margin-bottom:0in; margin-bottom:.0001pt;'><span style='color:#333333; background:white;'>...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 36. Petroleum Waterways
#    ID: https://www.arcgis.com/home/item.html?id=075a9258a71548db97cbd47c4a70f498&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 37. Petroleum Ports
#    ID: https://www.arcgis.com/home/item.html?id=90bb3d4ed42049188123704a1f437d16&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 38. Solid Biomass Resources
#    ID: https://www.arcgis.com/home/item.html?id=8e88b6990bd24434b9e915db598cea06&sublayer=0
#    Description: Source: https://www.nrel.gov/gis/assets/data/solid-biomass.20200228.zip<div><br /></div>...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 39. Geothermal Potential
#    ID: https://www.arcgis.com/home/item.html?id=6515281935cc4cc1afdd585358d0aee3&sublayer=0
#    Description: This dataset is a qualitative assessment of geothermal potential (Enhanced Geothermal System EGS) fo...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 40. US Census Regions Divisions
#    ID: https://www.arcgis.com/home/item.html?id=7a47706f0f5a4ebd82e4150e08c8c215&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 41. On Shore Wind Speed
#    ID: https://www.arcgis.com/home/item.html?id=4d380293a7e54330b73a657212004e60&sublayer=0
#    Description: <span style='font-family:&quot;Avenir Next W01&quot;, &quot;Avenir Next W00&quot;, &quot;Avenir Next...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 42. ShalePlay Midland Spraberry Lower Isopach EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=8ec5cde5c0574125be397cbc973f27d0&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 43. ShalePlay Midland SpraberryMiddle Boundary EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=c9a9d9019df641f2a920ab141ea50c73&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 44. ShalePlay Midland SpraberryUpper Boundary EIA 202111
#    ID: https://www.arcgis.com/home/item.html?id=18528a24567641988af02d6a26a8ba92&sublayer=0
#    Description: {{description}}...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 45. Major Tight Oil and Shale Gas Play - Three Forks Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=f933868852ea40c886295d2d23f49ce7&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 46. USA Short-Term Weather Warnings
#    ID: https://www.arcgis.com/home/item.html?id=bba3d0a070d34cea9a303c24a71d5190
#    Description: The National Weather Service issues warnings for severe weather that are imminent or actively occurr...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 47. NOAA Severe Thunderstorm Warnings
#    ID: https://www.arcgis.com/home/item.html?id=bba3d0a070d34cea9a303c24a71d5190&sublayer=0
#    Description: The National Weather Service issues warnings for severe weather that are imminent or actively occurr...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 48. NOAA Tornado Warnings
#    ID: https://www.arcgis.com/home/item.html?id=bba3d0a070d34cea9a303c24a71d5190&sublayer=1
#    Description: The National Weather Service issues warnings for severe weather that are imminent or actively occurr...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 49. NOAA Flash Flood Warnings
#    ID: https://www.arcgis.com/home/item.html?id=bba3d0a070d34cea9a303c24a71d5190&sublayer=2
#    Description: The National Weather Service issues warnings for severe weather that are imminent or actively occurr...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 50. NOAA Special Marine Warnings
#    ID: https://www.arcgis.com/home/item.html?id=bba3d0a070d34cea9a303c24a71d5190&sublayer=3
#    Description: The National Weather Service issues warnings for severe weather that are imminent or actively occurr...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 51. Satellite (MODIS) Thermal Hotspots and Fire Activity
#    ID: https://www.arcgis.com/home/item.html?id=b8f4033069f141729ffb298b7418b653
#    Description: This layer presents detectable thermal activity from MODIS satellites for the last 7 days. <a href='...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 52. MODIS Thermal (Last 48 hours)
#    ID: https://www.arcgis.com/home/item.html?id=b8f4033069f141729ffb298b7418b653&sublayer=0
#    Description: This layer presents detectable thermal activity from MODIS satellites for the last 7 days. <a href='...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 53. MODIS Thermal (Last 7 days)
#    ID: https://www.arcgis.com/home/item.html?id=b8f4033069f141729ffb298b7418b653&sublayer=1
#    Description: This layer presents detectable thermal activity from MODIS satellites for the last 7 days. <a href='...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 54. Recent Hurricanes, Cyclones and Typhoons
#    ID: https://www.arcgis.com/home/item.html?id=adfe292a67f8471a9d8230ef93294414
#    Description: <div>This layer features tropical storm (hurricanes, typhoons, cyclones) tracks, positions, and obse...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 55. Observed Position
#    ID: https://www.arcgis.com/home/item.html?id=adfe292a67f8471a9d8230ef93294414&sublayer=0
#    Description: <div>This layer features tropical storm (hurricanes, typhoons, cyclones) tracks, positions, and obse...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 56. Observed Track
#    ID: https://www.arcgis.com/home/item.html?id=adfe292a67f8471a9d8230ef93294414&sublayer=1
#    Description: <div>This layer features tropical storm (hurricanes, typhoons, cyclones) tracks, positions, and obse...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 57. Observed Wind Swath
#    ID: https://www.arcgis.com/home/item.html?id=adfe292a67f8471a9d8230ef93294414&sublayer=2
#    Description: <div>This layer features tropical storm (hurricanes, typhoons, cyclones) tracks, positions, and obse...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 58. Active Hurricanes, Cyclones and Typhoons
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 59. Forecast Position
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=0
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 60. Observed Position
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=1
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 61. Raw 1/10th Degree Data (All)
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=10
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 62. Observed Wind Swath
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=11
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 63. Forecast Track
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=2
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 64. Observed Track
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=3
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 65. Forecast Error Cone and Danger Area
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=4
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 66. Watches and Warnings
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=5
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 67. Tropical Storm Force (34kts)
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=7
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 68. Strong Tropical Storm (50kts)
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=8
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 69. Hurricane Force (64kts+)
#    ID: https://www.arcgis.com/home/item.html?id=248e7b5827a34b248647afb012c58787&sublayer=9
#    Description: <div>Hurricane tracks and positions provide information on where the storm has been, where it is cur...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 70. USA Current Wildfires
#    ID: https://www.arcgis.com/home/item.html?id=d957997ccee7408287a963600a77f61f
#    Description: <div>This layer presents the best-known point and perimeter locations of wildfire occurrences within...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 71. Current Incidents
#    ID: https://www.arcgis.com/home/item.html?id=d957997ccee7408287a963600a77f61f&sublayer=0
#    Description: <div>This layer presents the best-known point and perimeter locations of wildfire occurrences within...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 72. Current Perimeters
#    ID: https://www.arcgis.com/home/item.html?id=d957997ccee7408287a963600a77f61f&sublayer=1
#    Description: <div>This layer presents the best-known point and perimeter locations of wildfire occurrences within...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 73. National Weather Service Wind Speed Forecast
#    ID: https://www.arcgis.com/home/item.html?id=47ed83c3b4f943118e848fbfc33d119e&sublayer=0
#    Description: <div>This map displays the forecasted wind speeds over the next 72 hours across the contiguous Unite...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 74. National Weather Service Smoke Forecast
#    ID: https://www.arcgis.com/home/item.html?id=a98fd08751a5480c898b7cebe38807f4&sublayer=0
#    Description: This map displays projected visible surface smoke across the contiguous United States for the next 4...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 75. Satellite (VIIRS) Thermal Hotspots and Fire Activity
#    ID: https://www.arcgis.com/home/item.html?id=dece90af1a0242dcbf0ca36d30276aa3&sublayer=0
#    Description: <div>This layer presents detectable thermal activity from VIIRS satellites for the last 7 days. VIIR...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 76. National Weather Service Precipitation Forecast
#    ID: https://www.arcgis.com/home/item.html?id=f9e9283b9c9741d09aad633f68758bf6
#    Description: This map displays the <a href='https://vlab.noaa.gov/web/mdl/ndfd-information-links' target='_blank'...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 77. Amount by Time
#    ID: https://www.arcgis.com/home/item.html?id=f9e9283b9c9741d09aad633f68758bf6&sublayer=0
#    Description: This map displays the <a href='https://vlab.noaa.gov/web/mdl/ndfd-information-links' target='_blank'...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 78. Accumulation by Time
#    ID: https://www.arcgis.com/home/item.html?id=f9e9283b9c9741d09aad633f68758bf6&sublayer=1
#    Description: This map displays the <a href='https://vlab.noaa.gov/web/mdl/ndfd-information-links' target='_blank'...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 79. Cumulative Total
#    ID: https://www.arcgis.com/home/item.html?id=f9e9283b9c9741d09aad633f68758bf6&sublayer=2
#    Description: This map displays the <a href='https://vlab.noaa.gov/web/mdl/ndfd-information-links' target='_blank'...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 80. U.S. Electric Power Transmission Lines
#    ID: https://www.arcgis.com/home/item.html?id=d4090758322c4d32a4cd002ffaa0aa12&sublayer=0
#    Description: <div style='text-align:center;'><font color='#000000'><font size='5'>U.S. Electric Power Transmissio...
#    Available formats: GeoServices REST API, wfs, GDB, GPKG, XLSX, wmts, Web Page, ZIP, GeoJSON, KML, OGCFeat, TXT, CSV, ArcGIS GeoServices REST API
#
# 81. Power Plants
#    ID: https://www.arcgis.com/home/item.html?id=bf5c5110b1b944d299bb683cdbd02d2a&sublayer=0
#    Description: <div style='text-align:Left;'><div><div><p style='margin:8 0 11 0;'><span>The attribute data for thi...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 82. USA Census Tract Boundaries
#    ID: https://www.arcgis.com/home/item.html?id=20f5d275113e4066bf311236d9dcc3d4&sublayer=0
#    Description: <div><span>This layer presents the 2020 U.S. Census Tract boundaries of
# the United States in the 50...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 83. Petroleum Product Terminals
#    ID: https://www.arcgis.com/home/item.html?id=c3c2e337bee54706a3564b8889b8848d&sublayer=36
#    Description: <div style='text-align:Left;'><div><div><p><span>The attribute data for this point dataset come from...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 84. Natural Gas Underground Storage
#    ID: https://www.arcgis.com/home/item.html?id=beffe709475c45909ff7423426ccb220&sublayer=39
#    Description: <div style='text-align:Left;'><div><div><p style='margin:8 0 11 0;'><span>The attribute data for thi...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 85. Coal Mines
#    ID: https://www.arcgis.com/home/item.html?id=9fea95bf1add412d88b246d121f3b8c7&sublayer=247
#    Description: <div style='text-align:Left;'><div><div><p style='margin:0 0 11 0;'><span style='font-size:12pt'>The...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 86. Electric Retail Service Territories
#    ID: https://www.arcgis.com/home/item.html?id=4ee07fd24c0b47578c5b11017a7eb3ac&sublayer=0
#    Description: This feature class/shapefile represents electric power retail service territories. These are areas s...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 87. US Coal Fields
#    ID: https://www.arcgis.com/home/item.html?id=13ad01f317f74e5989c3ee199496fa32&sublayer=0
#    Description: This dataset is a polygon shapefile representing the most recent
# update of the coal fields of the co...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 88. USA SSURGO - Soil Hydrologic Group
#    ID: https://www.arcgis.com/home/item.html?id=be2124509b064754875b8f0d6176cc4c
#    Description: <div>When rain falls over land, a portion of it runs off into stream channels and storm water system...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 89. USA Urban Areas
#    ID: https://www.arcgis.com/home/item.html?id=432bb9246fdd467c88136e6ffeac2762
#    Description: <div><div><font color='#b22222'>Important Note:</font><b><b> This item is in <a href='https://goto.a...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 90. USA Urban Areas (over 1:1.5M)
#    ID: https://www.arcgis.com/home/item.html?id=432bb9246fdd467c88136e6ffeac2762&sublayer=1
#    Description: <div><div><font color='#b22222'>Important Note:</font><b><b> This item is in <a href='https://goto.a...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 91. USA Urban Areas (1:500k-1.5M)
#    ID: https://www.arcgis.com/home/item.html?id=432bb9246fdd467c88136e6ffeac2762&sublayer=2
#    Description: <div><div><font color='#b22222'>Important Note:</font><b><b> This item is in <a href='https://goto.a...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 92. USA Urban Areas (below 1:500k)
#    ID: https://www.arcgis.com/home/item.html?id=432bb9246fdd467c88136e6ffeac2762&sublayer=3
#    Description: <div><div><font color='#b22222'>Important Note:</font><b><b> This item is in <a href='https://goto.a...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 93. USA Railroads
#    ID: https://www.arcgis.com/home/item.html?id=d209f26edc86485a9c631311e50d9940&sublayer=0
#    Description: USA Railroads is a comprehensive database of the nation's railway system at 1:24,000 to 1:100,000 sc...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 94. USA Census States
#    ID: https://www.arcgis.com/home/item.html?id=774019f31f8549c39b5c72f149bbe74e&sublayer=0
#    Description: <div><span>This layer presents the 2020 U.S. Census State boundaries of
# the United States in the 50...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 95. USA Census Populated Place Areas
#    ID: https://www.arcgis.com/home/item.html?id=d8e6e822e6b44d80b4d3b5fe7538576d&sublayer=0
#    Description: <div style="text-align:Left;"><div><div><p>U.S. Census Populated Place Areas represents the 2020 U.S...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 96. USA Census Counties
#    ID: https://www.arcgis.com/home/item.html?id=14c5450526a8430298b2fa74da12c2f4&sublayer=0
#    Description: <div>This layer presents the U.S. Census County (or County Equivalent) boundaries of the United Stat...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 97. US Wind Turbine Database
#    ID: https://www.arcgis.com/home/item.html?id=cb89c230f4d44163abd62eb18b0b94dd&sublayer=0
#    Description: The United States Wind Turbine Database (USWTDB) provides the locations of land-based and offshore w...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 98. Renewable Electricity Infrastructure and Resources Dashboard
#    ID: https://www.arcgis.com/home/item.html?id=77cde239acfb494b81a00e927574e430
#    Description: This application is designed to allow stakeholders to understand renewable infrastructure of the ele...
#    Available formats: Web Page
#
# 99. Hurricanes, Cyclones and Typhoons
#    ID: https://www.arcgis.com/home/item.html?id=3bb4d468e0224cd78355f7aaab28cf04
#    Description: <span style='font-family:&quot;Avenir Next W01&quot;, &quot;Avenir Next W00&quot;, &quot;Avenir Next...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 100. Tight Oil and Shale Gas Plays
#    ID: https://www.arcgis.com/home/item.html?id=ac6b8a0cf7b14d9882877984364fb112
#    Description: <span style='font-family:&quot;Avenir Next W01&quot;, &quot;Avenir Next W00&quot;, &quot;Avenir Next...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 101. Electricity
#    ID: https://www.arcgis.com/home/item.html?id=895faaf79d744f2ab3b72f8bd5778e68
#    Description: The Electricity web mapping application is a map of the electricity infrastructure in the U.S.   The...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 102. All Energy Infrastructure and Resources
#    ID: https://www.arcgis.com/home/item.html?id=5039a1a01ec34b6bbf0ab4fd57da5eb4
#    Description: The All Energy Infrastructure web mapping application is a map of all U.S. energy infrastructure tha...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 103. Natural Gas
#    ID: https://www.arcgis.com/home/item.html?id=3652f0f1860d45beb0fed27dc8a6fc8d
#    Description: Map of natural gas infrastructure and resources in the U.S.  The map enables users to visualize the ...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 104. Petroleum & Biofuels
#    ID: https://www.arcgis.com/home/item.html?id=e1c92d7601b9490697d22dfe2da1b4ac
#    Description: Map of petroleum / biofuel infrastructure and resources in the U.S.  The map enables users to visual...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 105. Flooding
#    ID: https://www.arcgis.com/home/item.html?id=dc09eb46d89e4893b6dce8ee0819d792
#    Description: Map of U.S. energy infrastructure and resources and National Weather Service (NWS) and National Ocea...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 106. Fossil Fuels
#    ID: https://www.arcgis.com/home/item.html?id=87080f7260bc42b5b8a035050094d950
#    Description: <span style='font-family:&quot;Avenir Next W01&quot;, &quot;Avenir Next W00&quot;, &quot;Avenir Next...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 107. Wildfires
#    ID: https://www.arcgis.com/home/item.html?id=0ed920c755e640b7a6c2e013ab2bfdac
#    Description: Map of U.S. energy infrastructure and resources and fire related data feeds from National Interagenc...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 108. Coal
#    ID: https://www.arcgis.com/home/item.html?id=65df045e1c0c4b609df86cc92be0bee4
#    Description: The Coal web mapping application is a map of coal infrastructure and resources in the U.S.  The map ...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 109. Natural gas wells
#    ID: https://www.arcgis.com/home/item.html?id=075201df777f4abcbbf47c42f86fdf1c
#    Description: <div style='text-align:Left; font-size:12pt;'><p><span>Natural Gas wells, optimized for display</spa...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 110. Oil wells
#    ID: https://www.arcgis.com/home/item.html?id=4f95e8dd268a4183b2219be3690f457b
#    Description: <div style='text-align:Left;font-size:12pt'><p><span>Oil and Natural Gas wells, optimized for displa...
#    Available formats: Web Page, ArcGIS GeoServices REST API
#
# 111. Uranium - Associated with Phosphate
#    ID: https://www.arcgis.com/home/item.html?id=b05fcd858b5f416c9368641351c3cee9&sublayer=0
#    Description: <DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>Data was compiled from published sources by US Geol...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 112. Natural Gas Storage Regions
#    ID: https://www.arcgis.com/home/item.html?id=1175d62a1b354fafb104638ed0097fa6&sublayer=0
#    Description: Natural gas storage regions in the lower 48 States, as of 11/19/2015.<div><br /></div><div>U.S. Ener...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 113. Natural Gas Trading Hubs
#    ID: https://www.arcgis.com/home/item.html?id=7277e49c57e345aaab9a12e9b116983f&sublayer=0
#    Description: <DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>Key natural gas trading hubs in the United States. ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 114. Petroleum Administration for Defense Districts (PADD)
#    ID: https://www.arcgis.com/home/item.html?id=7ac1fefcccb149d7a8b3cd1ddaab7585&sublayer=0
#    Description: A geographic aggregation of the 50 States and the District of Columbia into five Districts with PADD...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 115. Uranium - Identified Resource Areas
#    ID: https://www.arcgis.com/home/item.html?id=1ddc80916bb742cfb439fef2cfe56b8d&sublayer=0
#    Description: <DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>Data was compiled from published sources by US Geol...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 116. Uranium - NURE Favorable Areas
#    ID: https://www.arcgis.com/home/item.html?id=f5107f2b16e644f4a866c3994d2824ee&sublayer=0
#    Description: <DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>Data was compiled from published sources by US Geol...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 117. Major Tight Oil and Shale Gas Play - Niobrara Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=d9cf95f854ec4941968ee5efaf8c4218&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 118. Major Tight Oil and Shale Gas Play - Point Pleasant Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=0194aa9e1c884370993a0b0971937a19&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 119. Major Tight Oil and Shale Gas Play - Utica Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=f9b7adde2db74111bbf60616f12c3daf&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 120. Major Tight Oil and Shale Gas Play - Wolfcamp Isopach, 200-Foot Interval
#    ID: https://www.arcgis.com/home/item.html?id=24eb96be78f14c32a3de2f58575c8995&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 121. Major Tight Oil and Shale Gas Play - Utica Isopach (Thickness) in Feet
#    ID: https://www.arcgis.com/home/item.html?id=a1fb200fdad74eed964c76859453382b&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 122. Major Tight Oil and Shale Gas Play - Three Forks Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=9d79f7e3254245c6a238ba3f2480687c&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 123. Major Tight Oil and Shale Gas Play - Bakken Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=899658da8e734cd3aca80a40677fbb7c&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 124. Major Tight Oil and Shale Gas Play - Abo-Yeso Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=fffcd36a6c494170a31527f98030a032&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 125. Major Tight Oil and Shale Gas Play - Point Pleasant Isopach (Thickness) in Feet
#    ID: https://www.arcgis.com/home/item.html?id=e7077c31bcea4bd5bd52db6cbb5669d7&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 126. Major Tight Oil and Shale Gas Play - Eagle Ford Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=370aa054e5094813a04cddc21982e168&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 127. Major Tight Oil and Shale Gas Play - Niobrara Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=55b019fe100f439090ce8ccb9c9dc13d&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 128. Major Tight Oil and Shale Gas Play - Marcellus Isopach (Thickness) in Feet
#    ID: https://www.arcgis.com/home/item.html?id=3fa0b250844e4143bec5e0b36ca271ae&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 129. Major Tight Oil and Shale Gas Play - Bakken Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=e6c4847dd1bd44fc919b8c82274403dd&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 130. Major Tight Oil and Shale Gas Play - Niobrara Isopach (Thickness) in Feet
#    ID: https://www.arcgis.com/home/item.html?id=857c01f62b0540758f5d0bbb98158d22&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 131. Major Tight Oil and Shale Gas Play - Marcellus Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=3469dc431ed746228ca0e18ccbfee91d&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 132. Major Tight Oil and Shale Gas Play - Marcellus Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=a1784f443f7346f49b509cb2af8dd832&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 133. Major Tight Oil and Shale Gas Play - Wolfcamp Isopach, 400-Foot Interval
#    ID: https://www.arcgis.com/home/item.html?id=e1073d2dd7554341b045d9492c8f6b95&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 134. Major Tight Oil and Shale Gas Play - Marcellus Formation Extent
#    ID: https://www.arcgis.com/home/item.html?id=5a3d4fa1e0774526bac2b35dc52b7d49&sublayer=0
#    Description: ...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 135. Major Tight Oil and Shale Gas Play - Delaware Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=04ae03187dcf4eb9b3a815757e2a88fb&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 136. Major Tight Oil and Shale Gas Play - Eagle Ford Isopach (Thickness) in Feet
#    ID: https://www.arcgis.com/home/item.html?id=8209a93a3e9b4d09b14702e5986ad5d9&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 137. Major Tight Oil and Shale Gas Play - Utica Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=dd4832b39a014a2fbd58a38c12a20d53&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 138. Major Tight Oil and Shale Gas Play - Glorieta-Yeso Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=b9b88dbb1b1f4109955385146840a0a9&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 139. Major Tight Oil and Shale Gas Play - Bone Spring Play Extent
#    ID: https://www.arcgis.com/home/item.html?id=3137be80bfbd4913b91839ee2f3f85b8&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 140. Major Tight Oil and Shale Gas Play - Wolfcamp Play Delaware Extent
#    ID: https://www.arcgis.com/home/item.html?id=c6177c0e560347089143001cf0d4e5fb&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 141. Major Tight Oil and Shale Gas Play - Bakken Isopach (Thickness) in Feet
#    ID: https://www.arcgis.com/home/item.html?id=a663051a8f7741ccb08f52c433570fef&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 142. Major Tight Oil and Shale Gas Play - Wolfcamp Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=c186be34829a4f3ab5e991de81e068c5&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 143. Major Tight Oil and Shale Gas Play - Eagle Ford Elevation of Top in Feet
#    ID: https://www.arcgis.com/home/item.html?id=3cf18493ea074994a4bfeed1b65a1201&sublayer=0
#    Description: {{description}}...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 144. Tight Oil and Shale Gas Plays
#    ID: https://www.arcgis.com/home/item.html?id=3f001fba00dc4add8dbd00542d61e4da&sublayer=0
#    Description: <div style='text-align:Left;'><p><span>General areas for shale plays in the U.S. This 2021 update in...
#    Available formats: GDB, GPKG, XLSX, Web Page, ZIP, GeoJSON, KML, TXT, CSV, ArcGIS GeoServices REST API
#
# 145. Off Shore Wind Speed 90m (NREL)
#    ID: https://www.arcgis.com/home/item.html?id=ddc4fbdf89b54d63b24ad2f841bf1f86&sublayer=0
#    Description: Annual average offshore wind speed for the Atlantic Coast (Connecticut, Delaware, Georgia, Massachus...
#    Available formats: Web Page, ZIP, GeoJSON, KML, CSV, ArcGIS GeoServices REST API
#
# 📊 Found 145 datasets
#
# 🔍 Checking formats for: https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0
# Supported formats for https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0:
#   - GeoJSON
#   - Shapefile
#   - KML
#   - CSV
#   - JSON
#   - GeoTIFF
#
# 💾 Example: Download https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0 as GeoJSON
# file_path = explorer.download_dataset('https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0', 'GeoJSON')
# map_viz = explorer.visualize_dataset(file_path, 'https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0')
#
# 🏃 Attempting to download and visualize https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0...
# debug download_dataset = {'title': 'Solar Resources', 'description': "<span style='color:rgb(34, 34, 34); font-family:Roboto, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size:16px;'>From the National Solar Radiation Database (NSRDB)\xa0Physical Solar Model (PSM)</span>", 'data': {'@type': 'dcat:Dataset', 'identifier': 'https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0', 'landingPage': 'https://atlas-eia.opendata.arcgis.com/datasets/eia::solar-resources', 'title': 'Solar Resources', 'description': "<span style='color:rgb(34, 34, 34); font-family:Roboto, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size:16px;'>From the National Solar Radiation Database (NSRDB)\xa0Physical Solar Model (PSM)</span>", 'keyword': ['Solar', 'EIA', 'EIA.gov', 'Energy', 'Energy Information Administration', 'Renewable energy'], 'issued': '2020-09-09T18:15:04.000Z', 'modified': '2020-09-29T15:20:53.577Z', 'publisher': {'name': 'National Renewable Energy Laboratory'}, 'contactPoint': {'@type': 'vcard:Contact', 'fn': 'EIA.gov', 'hasEmail': "mailto:<a href='' rel='nofollow ugc'>contact the arcgis online administrator</a>"}, 'accessLevel': 'public', 'spatial': '-179.3600,17.4940,179.8800,59.9941', 'license': '', 'distribution': [{'@type': 'dcat:Distribution', 'title': 'ArcGIS Hub Dataset', 'format': 'Web Page', 'mediaType': 'text/html', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/datasets/eia::solar-resources'}, {'@type': 'dcat:Distribution', 'title': 'ArcGIS GeoService', 'format': 'ArcGIS GeoServices REST API', 'mediaType': 'application/json', 'accessURL': 'https://services7.arcgis.com/FGr1D95XCGALKXqM/arcgis/rest/services/Solar_Resources/FeatureServer/0'}, {'@type': 'dcat:Distribution', 'title': 'CSV', 'format': 'CSV', 'mediaType': 'text/csv', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/csv?layers=0'}, {'@type': 'dcat:Distribution', 'title': 'Shapefile', 'format': 'ZIP', 'mediaType': 'application/zip', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/shapefile?layers=0'}, {'@type': 'dcat:Distribution', 'title': 'GeoJSON', 'format': 'GeoJSON', 'mediaType': 'application/vnd.geo+json', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/geojson?layers=0'}, {'@type': 'dcat:Distribution', 'title': 'KML', 'format': 'KML', 'mediaType': 'application/vnd.google-earth.kml+xml', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/kml?layers=0'}], 'theme': ['geospatial']}}
# service_url not in dataset
# debug self.available_dataset => {'https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0': {'title': 'Solar Resources', 'description': "<span style='color:rgb(34, 34, 34); font-family:Roboto, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size:16px;'>From the National Solar Radiation Database (NSRDB)\xa0Physical Solar Model (PSM)</span>", 'data': {'@type': 'dcat:Dataset', 'identifier': 'https://www.arcgis.com/home/item.html?id=b3be0d7de6fa429d815a906aba84c4d7&sublayer=0', 'landingPage': 'https://atlas-eia.opendata.arcgis.com/datasets/eia::solar-resources', 'title': 'Solar Resources', 'description': "<span style='color:rgb(34, 34, 34); font-family:Roboto, &quot;Helvetica Neue&quot;, Helvetica, sans-serif; font-size:16px;'>From the National Solar Radiation Database (NSRDB)\xa0Physical Solar Model (PSM)</span>", 'keyword': ['Solar', 'EIA', 'EIA.gov', 'Energy', 'Energy Information Administration', 'Renewable energy'], 'issued': '2020-09-09T18:15:04.000Z', 'modified': '2020-09-29T15:20:53.577Z', 'publisher': {'name': 'National Renewable Energy Laboratory'}, 'contactPoint': {'@type': 'vcard:Contact', 'fn': 'EIA.gov', 'hasEmail': "mailto:<a href='' rel='nofollow ugc'>contact the arcgis online administrator</a>"}, 'accessLevel': 'public', 'spatial': '-179.3600,17.4940,179.8800,59.9941', 'license': '', 'distribution': [{'@type': 'dcat:Distribution', 'title': 'ArcGIS Hub Dataset', 'format': 'Web Page', 'mediaType': 'text/html', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/datasets/eia::solar-resources'}, {'@type': 'dcat:Distribution', 'title': 'ArcGIS GeoService', 'format': 'ArcGIS GeoServices REST API', 'mediaType': 'application/json', 'accessURL': 'https://services7.arcgis.com/FGr1D95XCGALKXqM/arcgis/rest/services/Solar_Resources/FeatureServer/0'}, {'@type': 'dcat:Distribution', 'title': 'CSV', 'format': 'CSV', 'mediaType': 'text/csv', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/csv?layers=0'}, {'@type': 'dcat:Distribution', 'title': 'Shapefile', 'format': 'ZIP', 'mediaType': 'application/zip', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/shapefile?layers=0'}, {'@type': 'dcat:Distribution', 'title': 'GeoJSON', 'format': 'GeoJSON', 'mediaType': 'application/vnd.geo+json', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/geojson?layers=0'}, {'@type': 'dcat:Distribution', 'title': 'KML', 'format': 'KML', 'mediaType': 'application/vnd.google-earth.kml+xml', 'accessURL': 'https://atlas-eia.opendata.arcgis.com/api/download/v1/items/b3be0d7de6fa429d815a906aba84c4d7/kml?layers=0'}], 'theme': ['geospatial']}}, 'https://www.arcgis.com/home/item.html?id=1fc907a553964de3b2ee5e9224360c43&sublayer=0': {'title': 'NERC Regions', 'description': '<DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>This polygon dataset represents approximate boundaries of the North American Electric Reliability Corporation (NERC) Regions.</SPAN></P></DIV></DIV></DIV>', 'data': {'@type': 'dcat:Dataset', 'identifier': 'https://www.arcgis.com/home/item.html?id=1fc907a553964de3b2ee5e9224360c43&sublayer=0', 'landingPage': 'https://atlas-eia.opendata.arcgis.com/datasets/eia::nerc-regions', 'title': 'NERC Regions', 'description': '<DIV STYLE="text-align:Left;"><DIV><DIV><P><SPAN>This polygon dataset represents approximate boundaries of the North American Electric Reliability Corporation (NERC) Regions.</SPAN></P></DIV></DIV></DIV>', 'keyword': ['electric grid', 'EIA', 'EIA.gov', 'Energy', 'U.S. Energy Information Administration'], 'issued': '2020-06-09T16:53:05.000Z', 'modified': '2022-10-27T15:57:18.635Z', 'publisher': {'name': 'U.S. Energy Information Administration'}, 'contactPoint': {'@type': 'vcard:Contact', 'fn': 'EIA.gov', 'hasEmail': "mailto:<a href='' rel='nofollow ugc'>contact the arcgis online administrator</a>"}, 'accessLevel': 'public', 'spat ...
#
# ==================================================
# NEXT STEPS
# ==================================================
# 1. Run: datasets = explorer.discover_datasets()
# 2. Choose a dataset ID from the results
# 3. Run: file_path = explorer.download_dataset('dataset_id', 'GeoJSON')
# 4. Run: map_viz = explorer.visualize_dataset(file_path, 'dataset_id')
# 5. The map_viz object will be an interactive Folium map you can explore!
